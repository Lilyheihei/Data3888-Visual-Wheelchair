# %%
#knn
from skimage import io
url = "https://upload.wikimedia.org/wikipedia/commons/e/e9/Map1NNReducedDataSet.png"
image = io.imread(url)
io.imshow(image)
print("     KNN Algorism")
io.show()
# Out:
#     KNN Algorism

# %%
import matplotlib.pyplot as plt #
import matplotlib.image as mpimg 
import numpy as np
lena = mpimg.imread('demo1.png')
lena.shape 
plt.imshow(lena) 
print("     Left Event")
plt.show()
# Out:
#      Left Event

# %%
import matplotlib.pyplot as plt #
import matplotlib.image as mpimg 
import numpy as np
lena = mpimg.imread('demo2.png')
lena.shape 
plt.imshow(lena) 
print("     Right Event")
plt.show()
# Out:
#      Right Event

# %%
import matplotlib.pyplot as plt #
import matplotlib.image as mpimg 
import numpy as np
lena = mpimg.imread('WORK.png')
lena.shape
plt.imshow(lena) 
print("     Working flow")
plt.show()
# Out:
#      Working flow
